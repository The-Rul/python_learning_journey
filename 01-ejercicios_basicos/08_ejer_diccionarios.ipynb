# %% [markdown]
# ## Ejercicio 1: solo diccionarios
# ### Enunciado
# Crea un programa para gestionar las notas de varios alumnos usando un diccionario. </br>
# El diccionario tendrá:
#  * como clave el nombre del alumno
#  * como valor su nota </br>
#
# Se pide:
# 1.	Crear un diccionario con al menos 5 alumnos y sus notas.
# 2.	Mostrar todas las parejas alumno -> nota.
# 3.	Pedir por teclado el nombre de un alumno y mostrar su nota.
# 4.	Indicar qué alumno tiene la nota más alta.
# 5.	Calcular la media de todas las notas.
# 6.	Mostrar solo los alumnos que tengan una nota mayor o igual que 5.

# %%
#alumnos_dict = {{"nombre":"Luis", "nota" : 7.6},{"nombre":"Maria", "nota" : 9.5},{"nombre":"Jorge", "nota" : 5.6},{"nombre":"Carmele", "nota" : 3.6},{"nombre":"Pepa", "nota" : 1.6}}

alumnos_dict = {
    "Luis": 7.6,
    "Maria": 9.5,
    "Jorge": 5.6,
    "Carmele": 3.6,
    "Pepa": 1.6,
    "Carmen": 4.4
}

# 1 Crear y mostrar
for nombre, nota in alumnos_dict.items():
    print(f"Alumno {nombre} tienen nota {nota}.")
# Out:
# Alumno Luis tienen nota 7.6.
# Alumno Maria tienen nota 9.5.
# Alumno Jorge tienen nota 5.6.
# Alumno Carmele tienen nota 3.6.
# Alumno Pepa tienen nota 1.6.
# Alumno Carmen tienen nota 4.4.

# %%
## Pedir y mostrar su nota
alumno = input("Mirar nota de alumno: ")
#if alumno in alumnos_dict:
print(f"La nota de {alumno} es {alumnos_dict.get(alumno)}")
print(f"La nota de {alumno} es {alumnos_dict[alumno]}")
#else:
print("No se ha encontrado el alumno")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 alumno = input("Mirar nota de alumno: ")
#       3 #if alumno in alumnos_dict:
# ----> 4 print(f"La no ta de {alumno} es {alumnos_dict.get(alumno)}")
#       5 print(f"La no ta de {alumno} es {alumnos_dict[alumno]}")
#       6 #else:
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1586, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\debugpy\_vendored\pydevd\pydevd.py:2199, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2196             from_this_thread.append(frame_custom_thread_id)
#    2198     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2199         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2201 frames_list = None
#    2203 if keep_suspended:
#    2204     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Roaming\Python\Python314\site-packages\debugpy\_vendored\pydevd\pydevd.py:2268, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2265                 queue.put(internal_cmd)
#    2266                 wait_timeout = TIMEOUT_FAST
# -> 2268         notify_event.wait(wait_timeout)
#    2269         notify_event.clear()
#    2271 finally:
#
# File c:\Users\Usuario\AppData\Local\Python\pythoncore-3.14-64\Lib\threading.py:669, in Event.wait(self, timeout)
#     667 signaled = self._flag
#     668 if not signaled:
# --> 669     signaled = self._cond.wait(timeout)
#     670 return signaled
#
# File c:\Users\Usuario\AppData\Local\Python\pythoncore-3.14-64\Lib\threading.py:373, in Condition.wait(self, timeout)
#     371 else:
#     372     if timeout > 0:
# --> 373         gotit = waiter.acquire(True, timeout)
#     374     else:
#     375         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
